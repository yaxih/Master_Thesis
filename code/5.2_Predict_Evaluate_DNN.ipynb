# %%
from __future__ import print_function, division
from collections import Counter
import csv
import numpy as np
import random
import sys
import os
import copy
import time
from datetime import datetime,timedelta
from math import log, sqrt
import pandas as pd
import distance
from keras.models import load_model
import matplotlib.pyplot as plt
from jellyfish._jellyfish import damerau_levenshtein_distance

# %% [markdown]
# # 1.Read file

# %%
eventlog = "env_permit.csv"
eventlog_name = "env_permit"
ori_eventlog="env_permit.csv"

# %%
# load model, set this to the model generated above
#model = load_model('output_files/models/helpdesk_DNN_model_16-0.56.h5')
#model = load_model('output_files/models/helpdesk_lowS_DNN_model_19-0.57.h5')
model = load_model('output_files/models/env_permit_DNN_model_04-3.81.h5')

# %% [markdown]
# # 1.1. Calculate Maxlen and Target labels
#
# to make sure the model is compile with different sized test set, the shape of the training set needs to be the same.
# Thus, maxlen is loaded as the maximum length of a trace from the original log, target_chars is loaded as all possible characters from the original log

# %%
ori_csvfile = open('../data/%s' % ori_eventlog, 'r')
print('original dataset',ori_eventlog)
spamreader = csv.reader(ori_csvfile, delimiter=',', quotechar='|')
next(spamreader, None)  # skip the headers
ascii_offset = 161
lines = [] #these are all the activity seq
timeseqs = [] #time sequences (differences between two events)
timeseqs2 = [] #time sequences (differences between the current and first)

#helper variables
lastcase = ''
line = ''
firstLine = True
times = []
times2 = []
numlines = 0
casestarttime = None
lasteventtime = None
for row in spamreader: #the rows are "CaseID,ActivityID,CompleteTimestamp"
    t = datetime.strptime(row[2], "%Y-%m-%d %H:%M:%S") #creates a datetime object from row[2]
    if row[0]!=lastcase:  #'lastcase' is to save the last executed case for the loop
        casestarttime = t
        lasteventtime = t
        lastcase = row[0]
        if not firstLine:
            lines.append(line)
            timeseqs.append(times)
            timeseqs2.append(times2)
        line = ''
        times = []
        times2 = []
        numlines+=1
    line+=chr(int(row[1])+ascii_offset)
    timesincelastevent = t - lasteventtime
    timesincecasestart = t - casestarttime
    timediff = 86400 * timesincelastevent.days + timesincelastevent.seconds  #time b/t current and last event
    timediff2 = 86400 * timesincecasestart.days + timesincecasestart.seconds #time b/t current and starting event
    times.append(timediff)
    times2.append(timediff2)
    lasteventtime = t
    firstLine = False
# add last case
lines.append(line)
timeseqs.append(times)
timeseqs2.append(times2)
numlines+=1
step = 1
sentences = []
softness = 0
next_chars = []
lines = list(map(lambda x: x+ '!',lines)) #add a delimiter symbol '!' to the end of each line
maxlen = max(map(lambda x: len(x),lines)) #find maximum line size
print('maxlen:',maxlen)
# next lines here to get all possible characters for events and annotate them with numbers
chars = list(map(lambda x: set(x),lines))
chars = list(set().union(*chars))
chars.sort()
target_chars = copy.copy(chars)
if '!' in chars:
    chars.remove('!')
print('total chars: {}, target chars: {}'.format(len(chars), len(target_chars)))
#get the target chars from the training set
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
target_char_indices = dict((c, i) for i, c in enumerate(target_chars))
target_indices_char = dict((i, c) for i, c in enumerate(target_chars))
print(indices_char)
# Out:
# original dataset env_permit.csv
# maxlen: 96
# total chars: 381, target chars: 382
# {0: '¢', 1: '£', 2: '¤', 3: '¥', 4: '¦', 5: '§', 6: '¨', 7: '©', 8: 'ª', 9: '«', 10: '¬', 11: '\xad', 12: '®', 13: '¯', 14: '°', 15: '±', 16: '²', 17: '³', 18: '´', 19: 'µ', 20: '¶', 21: '·', 22: '¸', 23: '¹', 24: 'º', 25: '»', 26: '¼', 27: '½', 28: '¾', 29: '¿', 30: 'À', 31: 'Á', 32: 'Â', 33: 'Ã', 34: 'Ä', 35: 'Å', 36: 'Æ', 37: 'Ç', 38: 'È', 39: 'É', 40: 'Ê', 41: 'Ë', 42: 'Ì', 43: 'Í', 44: 'Î', 45: 'Ï', 46: 'Ð', 47: 'Ñ', 48: 'Ò', 49: 'Ó', 50: 'Ô', 51: 'Õ', 52: 'Ö', 53: '×', 54: 'Ø', 55: 'Ù', 56: 'Ú', 57: 'Û', 58: 'Ü', 59: 'Ý', 60: 'Þ', 61: 'ß', 62: 'à', 63: 'á', 64: 'â', 65: 'ã', 66: 'ä', 67: 'å', 68: 'æ', 69: 'ç', 70: 'è', 71: 'é', 72: 'ê', 73: 'ë', 74: 'ì', 75: 'í', 76: 'î', 77: 'ï', 78: 'ð', 79: 'ñ', 80: 'ò', 81: 'ó', 82: 'ô', 83: 'õ', 84: 'ö', 85: '÷', 86: 'ø', 87: 'ù', 88: 'ú', 89: 'û', 90: 'ü', 91: 'ý', 92: 'þ', 93: 'ÿ', 94: 'Ā', 95: 'ā', 96: 'Ă', 97: 'ă', 98: 'Ą', 99: 'ą', 100: 'Ć', 101: 'ć', 102: 'Ĉ', 103: 'ĉ', 104: 'Ċ', 105: 'ċ', 106: 'Č', 107: 'č', 108: 'Ď', 109: 'ď', 110: 'Đ', 111: 'đ', 112: 'Ē', 113: 'ē', 114: 'Ĕ', 115: 'ĕ', 116: 'Ė', 117: 'ė', 118: 'Ę', 119: 'ę', 120: 'Ě', 121: 'ě', 122: 'Ĝ', 123: 'ĝ', 124: 'Ğ', 125: 'ğ', 126: 'Ġ', 127: 'ġ', 128: 'Ģ', 129: 'ģ', 130: 'Ĥ', 131: 'ĥ', 132: 'Ħ', 133: 'ħ', 134: 'Ĩ', 135: 'ĩ', 136: 'Ī', 137: 'ī', 138: 'Ĭ', 139: 'ĭ', 140: 'Į', 141: 'į', 142: 'İ', 143: 'ı', 144: 'Ĳ', 145: 'ĳ', 146: 'Ĵ', 147: 'ĵ', 148: 'Ķ', 149: 'ķ', 150: 'ĸ', 151: 'Ĺ', 152: 'ĺ', 153: 'Ļ', 154: 'ļ', 155: 'Ľ', 156: 'ľ', 157: 'Ŀ', 158: 'ŀ', 159: 'Ł', 160: 'ł', 161: 'Ń', 162: 'ń', 163: 'Ņ', 164: 'ņ', 165: 'Ň', 166: 'ň', 167: 'ŉ', 168: 'Ŋ', 169: 'ŋ', 170: 'Ō', 171: 'ō', 172: 'Ŏ', 173: 'ŏ', 174: 'Ő', 175: 'ő', 176: 'Œ', 177: 'œ', 178: 'Ŕ', 179: 'ŕ', 180: 'Ŗ', 181: 'ŗ', 182: 'Ř', 183: 'ř', 184: 'Ś', 185: 'ś', 186: 'Ŝ', 187: 'ŝ', 188: 'Ş', 189: 'ş', 190: 'Š', 191: 'š', 192: 'Ţ', 193: 'ţ', 194: 'Ť', 195: 'ť', 196: 'Ŧ', 197: 'ŧ', 198: 'Ũ', 199: 'ũ', 200: 'Ū', 201: 'ū', 202: 'Ŭ', 203: 'ŭ', 204: 'Ů', 205: 'ů', 206: 'Ű', 207: 'ű', 208: 'Ų', 209: 'ų', 210: 'Ŵ', 211: 'ŵ', 212: 'Ŷ', 213: 'ŷ', 214: 'Ÿ', 215: 'Ź', 216: 'ź', 217: 'Ż', 218: 'ż', 219: 'Ž', 220: 'ž', 221: 'ſ', 222: 'ƀ', 223: 'Ɓ', 224: 'Ƃ', 225: 'ƃ', 226: 'Ƅ', 227: 'ƅ', 228: 'Ɔ', 229: 'Ƈ', 230: 'ƈ', 231: 'Ɖ', 232: 'Ɗ', 233: 'Ƌ', 234: 'ƌ', 235: 'ƍ', 236: 'Ǝ', 237: 'Ə', 238: 'Ɛ', 239: 'Ƒ', 240: 'ƒ', 241: 'Ɠ', 242: 'Ɣ', 243: 'ƕ', 244: 'Ɩ', 245: 'Ɨ', 246: 'Ƙ', 247: 'ƙ', 248: 'ƚ', 249: 'ƛ', 250: 'Ɯ', 251: 'Ɲ', 252: 'ƞ', 253: 'Ɵ', 254: 'Ơ', 255: 'ơ', 256: 'Ƣ', 257: 'ƣ', 258: 'Ƥ', 259: 'ƥ', 260: 'Ʀ', 261: 'Ƨ', 262: 'ƨ', 263: 'Ʃ', 264: 'ƪ', 265: 'ƫ', 266: 'Ƭ', 267: 'ƭ', 268: 'Ʈ', 269: 'Ư', 270: 'ư', 271: 'Ʊ', 272: 'Ʋ', 273: 'Ƴ', 274: 'ƴ', 275: 'Ƶ', 276: 'ƶ', 277: 'Ʒ', 278: 'Ƹ', 279: 'ƹ', 280: 'ƺ', 281: 'ƻ', 282: 'Ƽ', 283: 'ƽ', 284: 'ƾ', 285: 'ƿ', 286: 'ǀ', 287: 'ǁ', 288: 'ǂ', 289: 'ǃ', 290: 'Ǆ', 291: 'ǅ', 292: 'ǆ', 293: 'Ǉ', 294: 'ǈ', 295: 'ǉ', 296: 'Ǌ', 297: 'ǋ', 298: 'ǌ', 299: 'Ǎ', 300: 'ǎ', 301: 'Ǐ', 302: 'ǐ', 303: 'Ǒ', 304: 'ǒ', 305: 'Ǔ', 306: 'ǔ', 307: 'Ǖ', 308: 'ǖ', 309: 'Ǘ', 310: 'ǘ', 311: 'Ǚ', 312: 'ǚ', 313: 'Ǜ', 314: 'ǜ', 315: 'ǝ', 316: 'Ǟ', 317: 'ǟ', 318: 'Ǡ', 319: 'ǡ', 320: 'Ǣ', 321: 'ǣ', 322: 'Ǥ', 323: 'ǥ', 324: 'Ǧ', 325: 'ǧ', 326: 'Ǩ', 327: 'ǩ', 328: 'Ǫ', 329: 'ǫ', 330: 'Ǭ', 331: 'ǭ', 332: 'Ǯ', 333: 'ǯ', 334: 'ǰ', 335: 'Ǳ', 336: 'ǲ', 337: 'ǳ', 338: 'Ǵ', 339: 'ǵ', 340: 'Ƕ', 341: 'Ƿ', 342: 'Ǹ', 343: 'ǹ', 344: 'Ǻ', 345: 'ǻ', 346: 'Ǽ', 347: 'ǽ', 348: 'Ǿ', 349: 'ǿ', 350: 'Ȁ', 351: 'ȁ', 352: 'Ȃ', 353: 'ȃ', 354: 'Ȅ', 355: 'ȅ', 356: 'Ȇ', 357: 'ȇ', 358: 'Ȉ', 359: 'ȉ', 360: 'Ȋ', 361: 'ȋ', 362: 'Ȍ', 363: 'ȍ', 364: 'Ȏ', 365: 'ȏ', 366: 'Ȑ', 367: 'ȑ', 368: 'Ȓ', 369: 'ȓ', 370: 'Ȕ', 371: 'ȕ', 372: 'Ȗ', 373: 'ȗ', 374: 'Ș', 375: 'ș', 376: 'Ț', 377: 'ț', 378: 'Ȝ', 379: 'ȝ', 380: 'Ȟ'}

# %% [markdown]
# # 2.Process Data

# %%
csvfile = open('../data/%s' % eventlog, 'r')
spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
next(spamreader, None)  # skip the headers
ascii_offset = 161

lastcase = ''
line = ''
firstLine = True
lines = []
caseids = []
timeseqs = []
timeseqs2 = []
times = []
times2 = []
numlines = 0
casestarttime = None
lasteventtime = None
for row in spamreader:
    t = time.strptime(row[2], "%Y-%m-%d %H:%M:%S")
    if row[0]!=lastcase:
        caseids.append(row[0])
        casestarttime = t
        lasteventtime = t
        lastcase = row[0]
        if not firstLine:
            lines.append(line)
            timeseqs.append(times)
            timeseqs2.append(times2)
        line = ''
        times = []
        numlines+=1
    line+=chr(int(row[1])+ascii_offset)
    timesincelastevent = datetime.fromtimestamp(time.mktime(t))-datetime.fromtimestamp(time.mktime(lasteventtime))
    timesincecasestart = datetime.fromtimestamp(time.mktime(t))-datetime.fromtimestamp(time.mktime(casestarttime))
    timediff = 86400 * timesincelastevent.days + timesincelastevent.seconds
    timediff2 = 86400 * timesincecasestart.days + timesincecasestart.seconds
    times.append(timediff)
    times2.append(timediff2)
    lasteventtime = t
    firstLine = False

# add last case
lines.append(line)
timeseqs.append(times)
timeseqs2.append(times2)
numlines+=1

#average time between events
divisor = np.mean([item for sublist in timeseqs for item in sublist])
print('divisor: {}'.format(divisor))
#average time between current and starting events
divisor2 = np.mean([item for sublist in timeseqs2 for item in sublist])
print('divisor2: {}'.format(divisor2))
# Out:
# divisor: 186908.12533381264
# divisor2: 5159390.008756163

# %%
elems_per_fold = int(round(numlines/3))
fold1 = lines[:elems_per_fold]
fold1_c = caseids[:elems_per_fold]
fold1_t = timeseqs[:elems_per_fold]
fold1_t2 = timeseqs2[:elems_per_fold]

fold2 = lines[elems_per_fold:2*elems_per_fold]
fold2_c = caseids[elems_per_fold:2*elems_per_fold]
fold2_t = timeseqs[elems_per_fold:2*elems_per_fold]
fold2_t2 = timeseqs2[elems_per_fold:2*elems_per_fold]

lines = fold1 + fold2
caseids = fold1_c + fold2_c
lines_t = fold1_t + fold2_t
lines_t2 = fold1_t2 + fold2_t2

step = 1
sentences = []
softness = 0
next_chars = []

# %%
lastcase = ''
line = ''
firstLine = True
lines = []
caseids = []
timeseqs = []  # relative time since previous event
timeseqs2 = [] # relative time since case start
timeseqs3 = [] # absolute time of previous event
times = []
times2 = []
times3 = []
numlines = 0
casestarttime = None
lasteventtime = None
csvfile = open('../data/%s' % eventlog, 'r')
spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
next(spamreader, None)  # skip the headers
for row in spamreader:
    t = time.strptime(row[2], "%Y-%m-%d %H:%M:%S")
    if row[0]!=lastcase:
        caseids.append(row[0])
        casestarttime = t
        lasteventtime = t
        lastcase = row[0]
        if not firstLine:        
            lines.append(line)
            timeseqs.append(times)
            timeseqs2.append(times2)
            timeseqs3.append(times3)
        line = ''
        times = []
        numlines+=1
    line+=chr(int(row[1])+ascii_offset)
    timesincelastevent = datetime.fromtimestamp(time.mktime(t))-datetime.fromtimestamp(time.mktime(lasteventtime))
    timesincecasestart = datetime.fromtimestamp(time.mktime(t))-datetime.fromtimestamp(time.mktime(casestarttime))
    midnight = datetime.fromtimestamp(time.mktime(t)).replace(hour=0, minute=0, second=0, microsecond=0)
    timesincemidnight = datetime.fromtimestamp(time.mktime(t))-midnight
    timediff = 86400 * timesincelastevent.days + timesincelastevent.seconds
    timediff2 = 86400 * timesincecasestart.days + timesincecasestart.seconds
    #timediff = log(timediff+1)
    times.append(timediff)
    times2.append(timediff2)
    times3.append(datetime.fromtimestamp(time.mktime(t)))
    lasteventtime = t
    firstLine = False

# add last case
lines.append(line)
timeseqs.append(times)
timeseqs2.append(times2)
timeseqs3.append(times3)
numlines+=1

# %% [markdown]
# ### Using last 1/3 as test set

# %%
fold3 = lines[2*elems_per_fold:]
fold3_c = caseids[2*elems_per_fold:]
fold3_t = timeseqs[2*elems_per_fold:]
fold3_t2 = timeseqs2[2*elems_per_fold:]
fold3_t3 = timeseqs3[2*elems_per_fold:]
#fold3_t4 = timeseqs4[2*elems_per_fold:]

lines = fold3
caseids = fold3_c
lines_t = fold3_t
lines_t2 = fold3_t2
lines_t3 = fold3_t3
#lines_t4 = fold1_t4 + fold2_t4

# set parameters
predict_size = 1

# %% [markdown]
# # 3.Prediction

# %%
# define helper functions
# Define the function to encode the input sequence
def encode(sentence, times, times3, maxlen=maxlen):
    num_features = len(chars)+5
    X = np.zeros((1, maxlen, num_features), dtype=np.float32)
    leftpad = maxlen-len(sentence)
    times2 = np.cumsum(times)
    for t, char in enumerate(sentence):
        midnight = times3[t].replace(hour=0, minute=0, second=0, microsecond=0)
        timesincemidnight = times3[t]-midnight
        multiset_abstraction = Counter(sentence[:t+1])
        for c in chars:
            if c==char:
                X[0, t+leftpad, char_indices[c]] = 1
        X[0, t+leftpad, len(chars)] = t+1
        X[0, t+leftpad, len(chars)+1] = times[t]/divisor
        X[0, t+leftpad, len(chars)+2] = times2[t]/divisor2
        X[0, t+leftpad, len(chars)+3] = timesincemidnight.seconds/86400
        X[0, t+leftpad, len(chars)+4] = times3[t].weekday()/7
    return X

# %%
# Define the function to get the predicted symbol from the output vector
def getSymbol(predictions):
    maxIndex = np.argmax(predictions)
    symbol = target_indices_char[maxIndex]
    return symbol

# %%
one_ahead_gt = []
one_ahead_pred = []

two_ahead_gt = []
two_ahead_pred = []

three_ahead_gt = []
three_ahead_pred = []

# %%
# make predictions
with open(f'output_files/results/DNN/{eventlog_name}_next_activity_%s' % eventlog, 'w') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    spamwriter.writerow(["CaseID", "Prefix length", "Groud truth", "Predicted", "Levenshtein", "Damerau"])
    for prefix_size in range(2,maxlen):
        print(prefix_size)
        for line, caseid, times, times3 in zip(lines, caseids, lines_t, lines_t3):
            times.append(0)
            cropped_line = ''.join(line[:prefix_size])
            cropped_times = times[:prefix_size]
            cropped_times3 = times3[:prefix_size]
            if '!' in cropped_line:
                continue # make no prediction for this case, since this case has ended already
            ground_truth = ''.join(line[prefix_size:prefix_size+predict_size])
            ground_truth_t = times[prefix_size:prefix_size+predict_size]
            predicted = ''
            for i in range(predict_size):
                if len(ground_truth)<=i:
                    continue
                enc = encode(cropped_line, cropped_times, cropped_times3)
                #print(enc)
                y = model.predict(enc)
                y_char = y[0]
                #print('y_char:',y_char)
                prediction = getSymbol(y_char)   
                #print('prediction:' + prediction)
                cropped_line += prediction
                #print('cropped_line:' + cropped_line)
                if prediction == '!': # end of case was just predicted, therefore, stop predicting further into the future
                    print('! predicted, end case')
                    break
                predicted += prediction
             
            output = []
            
            if len(ground_truth)>0:
                output.append(caseid)
                output.append(prefix_size)
                output.append(str(ground_truth).encode("utf-8"))
                output.append(str(predicted).encode("utf-8"))
                output.append(1 - distance.nlevenshtein(predicted, ground_truth))
                dls = 1 - (damerau_levenshtein_distance(str(predicted), str(ground_truth)) / max(len(predicted),len(ground_truth)))
                if dls<0:
                    dls=0 # we encountered problems with Damerau-Levenshtein Similarity on some linux machines where the default character encoding of the operating system caused it to be negative, this should never be the case
                output.append(dls)
                output.append(1 - distance.jaccard(predicted, ground_truth))

                spamwriter.writerow(output)
# Out:
# 2
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 40ms/step
# 3
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 4
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# ...
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 51ms/step
# 68
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 28ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 59ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 60ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 30ms/step
# ! predicted, end case
# 69
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 31ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 62ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 64ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 37ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 70
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 64ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 61ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 56ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 32ms/step
# ! predicted, end case
# 71
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 29ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 33ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 32ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 48ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 44ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 48ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 55ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 40ms/step
# ! predicted, end case
# 72
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 39ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 29ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 31ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 43ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 34ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 28ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 38ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 27ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 57ms/step
# ! predicted, end case
# 73
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 69ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 46ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 39ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 33ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 35ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 240ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 103ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 128ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 100ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 135ms/step
# ! predicted, end case
# 74
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 166ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 339ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 223ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 119ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 70ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 63ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 52ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 58ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 55ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 118ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 114ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 48ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 52ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 47ms/step
# ! predicted, end case
# 75
# 1/1 [==============================] - 0s 56ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 43ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 54ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 74ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 82ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 379ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 388ms/step
# ! predicted, end case
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 0s 154ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 108ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 65ms/step
# ! predicted, end case
# 76
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 44ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 44ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 40ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 47ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 101ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 51ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 59ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 49ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 42ms/step
# ! predicted, end case
# 77
# 1/1 [==============================] - 0s 38ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 35ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 40ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 31ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 32ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 43ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 43ms/step
# ! predicted, end case
# 78
# 1/1 [==============================] - 0s 35ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 38ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 41ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 45ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 56ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 37ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 37ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 36ms/step
# ! predicted, end case
# 79
# 1/1 [==============================] - 0s 32ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 39ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 44ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 31ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 40ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 40ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 49ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 38ms/step
# ! predicted, end case
# 80
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 44ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 42ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 35ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 47ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 48ms/step
# ! predicted, end case
# 81
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 58ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 43ms/step
# ! predicted, end case
# 82
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 53ms/step
# ! predicted, end case
# 83
# 1/1 [==============================] - 0s 55ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 70ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 71ms/step
# ! predicted, end case
# 84
# 1/1 [==============================] - 0s 68ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 60ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 53ms/step
# ! predicted, end case
# 85
# 1/1 [==============================] - 0s 56ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 60ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 54ms/step
# ! predicted, end case
# 86
# 1/1 [==============================] - 0s 64ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 56ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 70ms/step
# ! predicted, end case
# 87
# 1/1 [==============================] - 0s 71ms/step
# ! predicted, end case
# 1/1 [==============================] - 0s 63ms/step
# ! predicted, end case
# 88
# 1/1 [==============================] - 0s 59ms/step
# ! predicted, end case
# 89
# 1/1 [==============================] - 0s 67ms/step
# ! predicted, end case
# 90
# 91
# 92
# 93
# 94
# 95

# %% [markdown]
# # 4.Evaluation

# %%
from sklearn.metrics import accuracy_score, classification_report
ground_truth = []
predicted = []
with open(f'output_files/results/DNN/{eventlog_name}_next_activity_%s' % eventlog) as file:
    reader = csv.reader(file, delimiter=",")
    # Skip the header
    next(reader, None)
    for row in reader:
        # we do not evaluate the end activity of the case
        if len(row) >= 4 and row[2] and row[3]:
            ground_truth.append(row[2])
            predicted.append(row[3])

# %%
accuracy = accuracy_score(ground_truth, predicted)
print("Next activity accuracy: ", accuracy)
print(classification_report(ground_truth, predicted))
# Out:
# Next activity accuracy:  0.1644075207695671
# C:\Users\I541451\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\I541451\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          b''       0.00      0.00      0.00         0
#  b'\xc2\xa2'       0.00      0.00      0.00        28
#  b'\xc2\xa3'       0.00      0.00      0.00         1
#  b'\xc2\xa4'       0.00      0.00      0.00         1
#  b'\xc2\xa5'       0.00      0.00      0.00         1
#  b'\xc2\xaa'       0.00      0.00      0.00         1
#  b'\xc2\xb4'       0.00      0.00      0.00         0
#  b'\xc2\xb6'       0.00      0.00      0.00        28
#  b'\xc2\xb7'       0.00      0.00      0.00        28
#  b'\xc2\xb8'       0.00      0.00      0.00        15
#  b'\xc2\xb9'       0.00      0.00      0.00        16
#  b'\xc2\xba'       0.60      0.56      0.58       311
#  b'\xc2\xbb'       0.91      0.61      0.73       297
#  b'\xc2\xbc'       0.45      0.73      0.56       298
#  b'\xc2\xbd'       0.27      0.33      0.30       248
#  b'\xc2\xbe'       0.00      0.00      0.00         0
#  b'\xc2\xbf'       0.03      0.46      0.06        26
#  b'\xc3\x80'       0.00      0.00      0.00        18
#  b'\xc3\x81'       0.00      0.00      0.00         0
#  b'\xc3\x82'       0.00      0.00      0.00       299
#  b'\xc3\x83'       0.00      0.00      0.00       243
#  b'\xc3\x84'       0.16      0.62      0.25        68
#  b'\xc3\x85'       0.01      0.06      0.01        68
#  b'\xc3\x87'       0.50      0.12      0.20         8
#  b'\xc3\x88'       0.00      0.00      0.00        49
#  b'\xc3\x89'       0.00      0.00      0.00       171
#  b'\xc3\x8a'       0.00      0.00      0.00         5
#  b'\xc3\x8b'       0.00      0.00      0.00         6
#  b'\xc3\x8c'       0.17      0.22      0.19       267
#  b'\xc3\x8d'       0.00      0.00      0.00       224
#  b'\xc3\x8e'       0.00      0.00      0.00        82
#  b'\xc3\x8f'       0.00      0.00      0.00        83
#  b'\xc3\x90'       0.00      0.00      0.00         0
#  b'\xc3\x91'       0.00      0.00      0.00         0
#  b'\xc3\x92'       0.00      0.00      0.00         0
#  b'\xc3\x96'       0.42      0.19      0.27       277
#  b'\xc3\x97'       0.00      0.00      0.00        16
#  b'\xc3\x98'       0.00      0.00      0.00        17
#  b'\xc3\x99'       0.00      0.00      0.00        17
#  b'\xc3\x9a'       0.00      0.00      0.00         0
#  b'\xc3\x9d'       0.00      0.00      0.00        58
#  b'\xc3\xa0'       0.31      0.40      0.35       239
#  b'\xc3\xa1'       0.00      0.00      0.00       172
#  b'\xc3\xa2'       0.00      0.00      0.00         1
#  b'\xc3\xa3'       0.09      0.11      0.09       238
#  b'\xc3\xa4'       0.00      0.00      0.00         0
#  b'\xc3\xa5'       0.00      0.00      0.00         1
#  b'\xc3\xa6'       0.00      0.00      0.00         1
#  b'\xc3\xa7'       0.00      0.00      0.00         0
#  b'\xc3\xa8'       0.00      0.00      0.00       239
#  b'\xc3\xa9'       0.44      0.05      0.08       238
#  b'\xc3\xaa'       0.00      0.00      0.00         0
#  b'\xc3\xab'       0.00      0.00      0.00         0
#  b'\xc3\xac'       0.00      0.00      0.00         0
#  b'\xc3\xaf'       1.00      0.00      0.01       238
#  b'\xc3\xb0'       0.00      0.00      0.00         1
#  b'\xc3\xb1'       0.00      0.00      0.00         1
#  b'\xc3\xb2'       0.00      0.00      0.00         0
#  b'\xc3\xb4'       0.39      0.45      0.42       238
#  b'\xc3\xb5'       0.73      0.26      0.38       238
#  b'\xc3\xb6'       0.93      0.16      0.27       236
#  b'\xc3\xb9'       0.00      0.00      0.00         1
#  b'\xc3\xbc'       0.00      0.00      0.00         1
#  b'\xc3\xbd'       0.95      0.41      0.57       220
#  b'\xc3\xbe'       0.00      0.00      0.00        12
#  b'\xc3\xbf'       0.29      0.11      0.16        18
#  b'\xc4\x80'       0.00      0.00      0.00        18
#  b'\xc4\x81'       0.14      0.17      0.15        18
#  b'\xc4\x82'       0.00      0.00      0.00         6
#  b'\xc4\x83'       0.00      0.00      0.00         1
#  b'\xc4\x84'       0.00      0.00      0.00         1
#  b'\xc4\x85'       0.09      0.22      0.13        18
#  b'\xc4\x86'       0.00      0.00      0.00         6
#  b'\xc4\x87'       0.00      0.00      0.00        18
#  b'\xc4\x88'       0.00      0.00      0.00         0
#  b'\xc4\x89'       0.00      0.00      0.00        18
#  b'\xc4\x8a'       0.00      0.00      0.00         1
#  b'\xc4\x8b'       0.00      0.00      0.00        12
#  b'\xc4\x8c'       0.00      0.00      0.00        12
#  b'\xc4\x8d'       0.00      0.00      0.00        18
#  b'\xc4\x8e'       0.05      0.33      0.09        18
#  b'\xc4\x8f'       0.00      0.00      0.00         0
#  b'\xc4\x90'       0.24      0.21      0.23       219
#  b'\xc4\x91'       0.00      0.00      0.00       177
#  b'\xc4\x92'       0.09      0.33      0.14       232
#  b'\xc4\x93'       0.48      0.21      0.29       232
#  b'\xc4\x94'       0.00      0.00      0.00        18
#  b'\xc4\x95'       0.01      0.17      0.01        29
#  b'\xc4\x96'       0.00      0.00      0.00       231
#  b'\xc4\x97'       0.00      0.00      0.00       156
#  b'\xc4\x98'       0.00      0.00      0.00       200
#  b'\xc4\x99'       0.00      0.00      0.00        49
#  b'\xc4\x9a'       0.00      0.00      0.00       203
#  b'\xc4\x9b'       0.00      0.00      0.00        58
#  b'\xc4\x9c'       0.00      0.00      0.00        14
#  b'\xc4\x9d'       0.00      0.00      0.00        14
#  b'\xc4\x9e'       0.00      0.00      0.00        58
#  b'\xc4\x9f'       0.00      0.00      0.00       159
#  b'\xc4\xa0'       0.05      0.10      0.07       230
#  b'\xc4\xa1'       0.00      0.00      0.00         1
#  b'\xc4\xa2'       0.00      0.00      0.00         1
#  b'\xc4\xa3'       0.00      0.00      0.00         1
#  b'\xc4\xa4'       0.00      0.00      0.00       229
#  b'\xc4\xa5'       0.00      0.00      0.00         0
#  b'\xc4\xa6'       0.00      0.00      0.00       174
#  b'\xc4\xa7'       0.16      0.04      0.06       222
#  b'\xc4\xa8'       0.00      0.00      0.00       171
#  b'\xc4\xa9'       0.03      0.04      0.03       224
#  b'\xc4\xaa'       0.00      0.00      0.00       225
#  b'\xc4\xab'       0.00      0.00      0.00       219
#  b'\xc4\xac'       0.00      0.00      0.00       225
#  b'\xc4\xad'       0.00      0.00      0.00         8
#  b'\xc4\xae'       0.00      0.00      0.00        61
#  b'\xc4\xaf'       0.00      0.00      0.00       145
#  b'\xc4\xb0'       0.00      0.00      0.00         6
#  b'\xc4\xb1'       0.00      0.00      0.00         1
#  b'\xc4\xb2'       0.00      0.00      0.00         1
#  b'\xc4\xb3'       0.00      0.00      0.00         0
#  b'\xc4\xbb'       0.00      0.00      0.00         0
#  b'\xc4\xbd'       0.00      0.00      0.00         2
#  b'\xc4\xbe'       0.00      0.00      0.00         4
#  b'\xc4\xbf'       0.00      0.00      0.00        10
#  b'\xc5\x80'       0.00      0.00      0.00        33
#  b'\xc5\x81'       0.02      0.15      0.04        46
#  b'\xc5\x82'       0.00      0.00      0.00        30
#  b'\xc5\x83'       0.00      0.00      0.00        45
#  b'\xc5\x84'       0.00      0.00      0.00        45
#  b'\xc5\x85'       0.00      0.00      0.00        43
#  b'\xc5\x88'       0.97      0.47      0.63       309
#  b'\xc5\x89'       0.00      0.00      0.00         1
#  b'\xc5\x8a'       0.00      0.00      0.00         2
#  b'\xc5\x8b'       0.00      0.00      0.00         1
#  b'\xc5\x8c'       0.00      0.00      0.00         1
#  b'\xc5\x8d'       0.00      0.00      0.00         2
#  b'\xc5\x8e'       0.00      0.00      0.00         2
#  b'\xc5\x90'       0.00      0.00      0.00         2
#  b'\xc5\x91'       0.00      0.00      0.00         2
#  b'\xc5\x92'       0.08      0.40      0.13         5
#  b'\xc5\x93'       0.00      0.00      0.00        28
#  b'\xc5\x94'       0.98      0.54      0.70       305
#  b'\xc5\x95'       0.00      0.00      0.00         8
#  b'\xc5\x96'       0.67      0.50      0.57         8
#  b'\xc5\x97'       0.00      0.00      0.00         8
#  b'\xc5\x98'       0.00      0.00      0.00         8
#  b'\xc5\x99'       0.67      0.80      0.73         5
#  b'\xc5\x9a'       0.00      0.00      0.00         2
#  b'\xc5\x9b'       0.00      0.00      0.00         2
#  b'\xc5\x9c'       0.00      0.00      0.00         1
#  b'\xc5\x9d'       0.00      0.00      0.00         2
#  b'\xc5\x9e'       0.00      0.00      0.00        21
#  b'\xc5\x9f'       0.00      0.00      0.00        11
#  b'\xc5\xa0'       0.00      0.00      0.00         4
#  b'\xc5\xa1'       0.00      0.00      0.00        18
#  b'\xc5\xa2'       0.00      0.00      0.00        21
#  b'\xc5\xa3'       0.00      0.00      0.00        15
#  b'\xc5\xa4'       0.00      0.00      0.00        15
#  b'\xc5\xa5'       0.00      0.00      0.00        15
#  b'\xc5\xa8'       0.00      0.00      0.00         1
#  b'\xc5\xa9'       0.14      0.06      0.09        16
#  b'\xc5\xaa'       0.00      0.00      0.00         0
#  b'\xc5\xab'       0.00      0.03      0.01        32
#  b'\xc5\xae'       0.08      0.22      0.12        32
#  b'\xc5\xaf'       0.00      0.00      0.00        28
#  b'\xc5\xb0'       0.52      0.50      0.51        32
#  b'\xc5\xb1'       0.16      0.34      0.22        32
#  b'\xc5\xb2'       0.00      0.00      0.00        11
#  b'\xc5\xb3'       0.00      0.00      0.00        13
#  b'\xc5\xb4'       0.00      0.00      0.00        32
#  b'\xc5\xb5'       0.00      0.00      0.00        17
#  b'\xc5\xb6'       0.00      0.00      0.00        19
#  b'\xc5\xb8'       0.00      0.00      0.00        32
#  b'\xc5\xba'       0.00      0.00      0.00         0
#  b'\xc5\xbb'       0.00      0.00      0.00        16
#  b'\xc5\xbc'       0.00      0.00      0.00        27
#  b'\xc5\xbd'       0.00      0.00      0.00        29
#  b'\xc5\xbe'       0.00      0.00      0.00        30
#  b'\xc5\xbf'       0.00      0.00      0.00        13
#  b'\xc6\x80'       0.00      0.00      0.00         0
#  b'\xc6\x81'       0.00      0.00      0.00         0
#  b'\xc6\x84'       0.00      0.00      0.00         2
#  b'\xc6\x85'       0.00      0.00      0.00         2
#  b'\xc6\x86'       0.00      0.00      0.00         2
#  b'\xc6\x87'       0.00      0.00      0.00         2
#  b'\xc6\x88'       0.00      0.00      0.00         2
#  b'\xc6\x89'       0.00      0.00      0.00         2
#  b'\xc6\x8a'       0.00      0.00      0.00         1
#  b'\xc6\x8b'       0.00      0.00      0.00         1
#  b'\xc6\x8c'       0.00      0.00      0.00         2
#  b'\xc6\x8d'       0.00      0.00      0.00         2
#  b'\xc6\x8e'       0.00      0.00      0.00         2
#  b'\xc6\x8f'       0.00      0.00      0.00         2
#  b'\xc6\x92'       0.08      0.04      0.06       326
#  b'\xc6\x93'       0.01      0.01      0.01        82
#  b'\xc6\x94'       0.00      0.00      0.00        36
#  b'\xc6\x95'       0.12      0.35      0.18        79
#  b'\xc6\x96'       0.22      0.10      0.14        79
#  b'\xc6\x97'       0.00      0.00      0.00        81
#  b'\xc6\x98'       0.12      0.74      0.21        77
#  b'\xc6\x99'       0.15      0.03      0.05        68
#  b'\xc6\x9a'       0.00      0.00      0.00        68
#  b'\xc6\x9b'       0.00      0.00      0.00         5
#  b'\xc6\x9c'       0.00      0.00      0.00        57
#  b'\xc6\x9d'       0.00      0.00      0.00         4
#  b'\xc6\x9e'       0.00      0.00      0.00         1
#  b'\xc6\x9f'       0.00      0.00      0.00         1
#  b'\xc6\xa0'       0.00      0.00      0.00        13
#  b'\xc6\xa1'       0.00      0.00      0.00        11
#  b'\xc6\xa2'       0.00      0.00      0.00        12
#  b'\xc6\xa3'       0.21      0.25      0.23        12
#  b'\xc6\xa4'       0.00      0.00      0.00         7
#  b'\xc6\xa5'       0.00      0.00      0.00         7
#  b'\xc6\xa6'       0.00      0.00      0.00        12
#  b'\xc6\xa7'       0.00      0.00      0.00         4
#  b'\xc6\xa8'       0.00      0.00      0.00         5
#  b'\xc6\xa9'       0.00      0.00      0.00        12
#  b'\xc6\xab'       0.00      0.00      0.00        11
#  b'\xc6\xac'       0.00      0.00      0.00         3
#  b'\xc6\xad'       0.00      0.00      0.00        11
#  b'\xc6\xae'       0.00      0.00      0.00        12
#  b'\xc6\xaf'       0.00      0.00      0.00        11
#  b'\xc6\xb0'       0.00      0.00      0.00         2
#  b'\xc6\xb1'       0.00      0.00      0.00         3
#  b'\xc6\xb2'       0.00      0.00      0.00         3
#  b'\xc6\xb3'       0.00      0.00      0.00         0
#  b'\xc6\xb4'       0.00      0.00      0.00         3
#  b'\xc6\xb7'       0.64      0.73      0.68       238
#  b'\xc6\xb8'       0.00      0.00      0.00         2
#  b'\xc6\xb9'       0.00      0.00      0.00         1
#  b'\xc6\xba'       0.00      0.00      0.00         1
#  b'\xc6\xbb'       0.00      0.00      0.00         0
#  b'\xc6\xbc'       0.06      0.11      0.08        18
#  b'\xc6\xbe'       0.00      0.00      0.00        12
#  b'\xc6\xbf'       0.00      0.00      0.00        16
#  b'\xc7\x80'       0.00      0.00      0.00         2
#  b'\xc7\x81'       0.00      0.00      0.00         0
#  b'\xc7\x82'       0.00      0.00      0.00        18
#  b'\xc7\x83'       0.01      0.25      0.02         4
#  b'\xc7\x84'       0.00      0.00      0.00         1
#  b'\xc7\x85'       0.00      0.00      0.00         0
#  b'\xc7\x86'       0.00      0.00      0.00        12
#  b'\xc7\x87'       0.01      0.07      0.02        15
#  b'\xc7\x88'       0.00      0.00      0.00        12
#  b'\xc7\x89'       0.04      0.06      0.05        18
#  b'\xc7\x8a'       0.00      0.00      0.00        18
#  b'\xc7\x8b'       0.00      0.00      0.00         9
#  b'\xc7\x8c'       0.25      0.07      0.11        15
#  b'\xc7\x8d'       0.00      0.00      0.00         3
#  b'\xc7\x8e'       0.00      0.00      0.00         3
#  b'\xc7\x90'       0.00      0.00      0.00         3
#  b'\xc7\x91'       0.00      0.00      0.00         3
#  b'\xc7\x92'       0.00      0.00      0.00         3
#  b'\xc7\x93'       0.00      0.00      0.00         3
#  b'\xc7\x97'       0.00      0.00      0.00         0
#  b'\xc7\x98'       0.00      0.00      0.00         0
#  b'\xc7\x9e'       0.97      0.47      0.64       228
#  b'\xc7\xa1'       0.00      0.00      0.00        17
#  b'\xc7\xa2'       0.00      0.00      0.00        17
#  b'\xc7\xa3'       0.00      0.00      0.00        16
#  b'\xc7\xa4'       0.00      0.00      0.00        16
#  b'\xc7\xa5'       0.00      0.00      0.00        16
#  b'\xc7\xa6'       0.00      0.00      0.00        16
#  b'\xc7\xa7'       0.00      0.00      0.00         1
#  b'\xc7\xa8'       0.00      0.00      0.00        15
#  b'\xc7\xa9'       0.00      0.00      0.00         7
#  b'\xc7\xaa'       0.00      0.00      0.00        14
#  b'\xc7\xab'       0.00      0.00      0.00        16
#  b'\xc7\xac'       0.00      0.00      0.00        15
#  b'\xc7\xaf'       0.00      0.00      0.00        15
#  b'\xc7\xb0'       0.00      0.00      0.00        15
#  b'\xc7\xb1'       0.00      0.00      0.00        14
#  b'\xc7\xb2'       0.00      0.00      0.00        14
#  b'\xc7\xb9'       0.00      0.00      0.00        15
#  b'\xc7\xba'       0.00      0.00      0.00        15
#  b'\xc7\xbb'       0.00      0.00      0.00        15
#  b'\xc7\xbc'       0.00      0.00      0.00         5
#  b'\xc8\x82'       0.00      0.00      0.00         3
#  b'\xc8\x88'       0.00      0.00      0.00       158
#  b'\xc8\x89'       0.00      0.00      0.00         5
#  b'\xc8\x8a'       0.00      0.00      0.00         3
#  b'\xc8\x8b'       0.00      0.00      0.00         5
#  b'\xc8\x8c'       0.00      0.00      0.00         1
#  b'\xc8\x8d'       0.00      0.00      0.00         1
#  b'\xc8\x8e'       0.00      0.00      0.00         1
#  b'\xc8\x8f'       0.00      0.00      0.00         1
#  b'\xc8\x90'       0.00      0.00      0.00         1
#  b'\xc8\x91'       0.00      0.00      0.00         1
#  b'\xc8\x92'       0.00      0.00      0.00         1
#  b'\xc8\x93'       0.00      0.00      0.00         1
#  b'\xc8\x94'       0.00      0.00      0.00         1
#  b'\xc8\x95'       0.00      0.00      0.00         1
#  b'\xc8\x96'       0.00      0.00      0.00         1
#  b'\xc8\x97'       0.00      0.00      0.00         1
#  b'\xc8\x98'       0.00      0.00      0.00         1
#  b'\xc8\x99'       0.00      0.00      0.00         1
#  b'\xc8\x9b'       0.00      0.00      0.00         1
#  b'\xc8\x9c'       0.00      0.00      0.00         0
#  b'\xc8\x9d'       0.00      0.00      0.00         1
#
#     accuracy                           0.16     13722
#    macro avg       0.06      0.05      0.04     13722
# weighted avg       0.24      0.16      0.17     13722
# C:\Users\I541451\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\I541451\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\I541451\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\I541451\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# convert classification report to dataframe
report = classification_report(ground_truth, predicted, output_dict=True)
df = pd.DataFrame(report).transpose()

# Save DataFrame to CSV file
df.to_csv(f'output_files/results/DNN/{eventlog_name}_Report.csv')
# Out:
# C:\Users\I541451\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\I541451\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\I541451\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\I541451\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\I541451\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\I541451\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
