# %%
from __future__ import print_function, division
from collections import Counter
import csv
import numpy as np
import random
import sys
import os
import copy
import time
from datetime import datetime,timedelta
from math import log, sqrt
import pandas as pd
import distance
from keras.models import load_model
import matplotlib.pyplot as plt
from jellyfish._jellyfish import damerau_levenshtein_distance

# %% [markdown]
# # 1.Read file

# %%
eventlog = "preprocessed_env_permit_lowV.csv"
eventlog_name = "env_permit_lowV"

# %%
csvfile = open('../data/%s' % eventlog, 'r')
spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
next(spamreader, None)  # skip the headers
ascii_offset = 161

# %% [markdown]
# # 2.Process Data

# %%
csvfile = open('../data/%s' % eventlog, 'r')
spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
next(spamreader, None)  # skip the headers
ascii_offset = 161

lastcase = ''
line = ''
firstLine = True
lines = []
caseids = []
timeseqs = []
timeseqs2 = []
times = []
times2 = []
numlines = 0
casestarttime = None
lasteventtime = None
for row in spamreader:
    t = time.strptime(row[2], "%Y-%m-%d %H:%M:%S")
    if row[0]!=lastcase:
        caseids.append(row[0])
        casestarttime = t
        lasteventtime = t
        lastcase = row[0]
        if not firstLine:
            lines.append(line)
            timeseqs.append(times)
            timeseqs2.append(times2)
        line = ''
        times = []
        numlines+=1
    line+=chr(int(row[1])+ascii_offset)
    timesincelastevent = datetime.fromtimestamp(time.mktime(t))-datetime.fromtimestamp(time.mktime(lasteventtime))
    timesincecasestart = datetime.fromtimestamp(time.mktime(t))-datetime.fromtimestamp(time.mktime(casestarttime))
    timediff = 86400 * timesincelastevent.days + timesincelastevent.seconds
    timediff2 = 86400 * timesincecasestart.days + timesincecasestart.seconds
    times.append(timediff)
    times2.append(timediff2)
    lasteventtime = t
    firstLine = False

# add last case
lines.append(line)
timeseqs.append(times)
timeseqs2.append(times2)
numlines+=1

#average time between events
divisor = np.mean([item for sublist in timeseqs for item in sublist])
print('divisor: {}'.format(divisor))
#average time between current and starting events
divisor2 = np.mean([item for sublist in timeseqs2 for item in sublist])
print('divisor2: {}'.format(divisor2))
# Out:
# divisor: 214878.4761088447
# divisor2: 4679926.187418627

# %%
elems_per_fold = int(round(numlines/3))
fold1 = lines[:elems_per_fold]
fold1_c = caseids[:elems_per_fold]
fold1_t = timeseqs[:elems_per_fold]
fold1_t2 = timeseqs2[:elems_per_fold]

fold2 = lines[elems_per_fold:2*elems_per_fold]
fold2_c = caseids[elems_per_fold:2*elems_per_fold]
fold2_t = timeseqs[elems_per_fold:2*elems_per_fold]
fold2_t2 = timeseqs2[elems_per_fold:2*elems_per_fold]

lines = fold1 + fold2
caseids = fold1_c + fold2_c
lines_t = fold1_t + fold2_t
lines_t2 = fold1_t2 + fold2_t2

step = 1
sentences = []
softness = 0
next_chars = []
lines = list(map(lambda x: x+'!',lines))
maxlen = max(map(lambda x: len(x),lines))

chars = list(map(lambda x : set(x),lines))
chars = list(set().union(*chars))
chars.sort()
target_chars = copy.copy(chars)
chars.remove('!')
print('total chars: {}, target chars: {}'.format(len(chars), len(target_chars)))
char_indices = {c: i for i, c in enumerate(chars)}
indices_char = {i: c for i, c in enumerate(chars)}
target_char_indices = {c: i for i, c in enumerate(target_chars)}
target_indices_char = {i: c for i, c in enumerate(target_chars)}
print(indices_char)
# Out:
# total chars: 203, target chars: 204
# {0: '¢', 1: '§', 2: '¨', 3: '©', 4: 'ª', 5: '°', 6: '±', 7: '³', 8: '¶', 9: '¸', 10: '¹', 11: 'º', 12: '»', 13: '¼', 14: '½', 15: '¾', 16: '¿', 17: 'À', 18: 'Á', 19: 'Ä', 20: 'Å', 21: 'Ç', 22: 'Ê', 23: 'Ì', 24: 'Î', 25: 'Ï', 26: 'Ð', 27: 'Ñ', 28: 'Ò', 29: 'Ó', 30: 'Ô', 31: 'Õ', 32: 'Ö', 33: 'Ø', 34: 'Ù', 35: 'Ú', 36: 'Ý', 37: 'Þ', 38: 'ß', 39: 'à', 40: 'á', 41: 'ã', 42: 'ä', 43: 'æ', 44: 'ç', 45: 'è', 46: 'é', 47: 'ê', 48: 'ë', 49: 'ì', 50: 'í', 51: 'î', 52: 'ï', 53: 'ò', 54: 'ó', 55: 'ô', 56: 'õ', 57: 'ö', 58: '÷', 59: 'ø', 60: 'ú', 61: 'û', 62: 'ü', 63: 'ý', 64: 'ÿ', 65: 'Ā', 66: 'ā', 67: 'ą', 68: 'ć', 69: 'Ĉ', 70: 'ĉ', 71: 'č', 72: 'Ď', 73: 'ď', 74: 'Đ', 75: 'Ē', 76: 'ē', 77: 'ĕ', 78: 'Ė', 79: 'Ě', 80: 'Ġ', 81: 'Ĥ', 82: 'ĥ', 83: 'ħ', 84: 'ĩ', 85: 'İ', 86: 'Ĳ', 87: 'ĳ', 88: 'Ĵ', 89: 'ĵ', 90: 'Ķ', 91: 'ķ', 92: 'ĸ', 93: 'Ĺ', 94: 'ĺ', 95: 'Ļ', 96: 'ļ', 97: 'Ľ', 98: 'Ł', 99: 'Ņ', 100: 'ņ', 101: 'Ň', 102: 'ň', 103: 'Ŋ', 104: 'ŋ', 105: 'ŏ', 106: 'Œ', 107: 'Ŕ', 108: 'ŕ', 109: 'Ŗ', 110: 'ŗ', 111: 'Ř', 112: 'ř', 113: 'Ś', 114: 'ŝ', 115: 'Ş', 116: 'š', 117: 'Ť', 118: 'ť', 119: 'Ŧ', 120: 'ŧ', 121: 'Ũ', 122: 'ũ', 123: 'Ū', 124: 'ū', 125: 'Ŭ', 126: 'ŭ', 127: 'Ů', 128: 'Ű', 129: 'ű', 130: 'ų', 131: 'ŷ', 132: 'Ź', 133: 'ź', 134: 'ƀ', 135: 'Ɓ', 136: 'Ƃ', 137: 'ƃ', 138: 'Ƅ', 139: 'ƅ', 140: 'Ɔ', 141: 'Ɗ', 142: 'Ƌ', 143: 'ƌ', 144: 'Ɛ', 145: 'Ƒ', 146: 'ƒ', 147: 'Ɠ', 148: 'ƕ', 149: 'Ɩ', 150: 'Ƙ', 151: 'ƙ', 152: 'Ơ', 153: 'Ƣ', 154: 'ƣ', 155: 'ƥ', 156: 'ƪ', 157: 'Ƭ', 158: 'Ʈ', 159: 'Ʊ', 160: 'Ʋ', 161: 'Ƴ', 162: 'Ƶ', 163: 'ƶ', 164: 'Ʒ', 165: 'ƻ', 166: 'Ƽ', 167: 'ƽ', 168: 'ƿ', 169: 'ǁ', 170: 'ǃ', 171: 'ǅ', 172: 'Ǉ', 173: 'ǉ', 174: 'ǌ', 175: 'ǎ', 176: 'Ǐ', 177: 'ǐ', 178: 'Ǒ', 179: 'ǒ', 180: 'Ǔ', 181: 'ǔ', 182: 'Ǖ', 183: 'ǖ', 184: 'Ǘ', 185: 'ǘ', 186: 'Ǚ', 187: 'ǚ', 188: 'Ǜ', 189: 'ǜ', 190: 'ǝ', 191: 'Ǟ', 192: 'ǟ', 193: 'Ǡ', 194: 'ǣ', 195: 'ǫ', 196: 'Ǯ', 197: 'ǳ', 198: 'Ƿ', 199: 'ǹ', 200: 'Ǽ', 201: 'ȋ', 202: 'Ȝ'}

# %%
lastcase = ''
line = ''
firstLine = True
lines = []
caseids = []
timeseqs = []  # relative time since previous event
timeseqs2 = [] # relative time since case start
timeseqs3 = [] # absolute time of previous event
times = []
times2 = []
times3 = []
numlines = 0
casestarttime = None
lasteventtime = None
csvfile = open('../data/%s' % eventlog, 'r')
spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
next(spamreader, None)  # skip the headers
for row in spamreader:
    t = time.strptime(row[2], "%Y-%m-%d %H:%M:%S")
    if row[0]!=lastcase:
        caseids.append(row[0])
        casestarttime = t
        lasteventtime = t
        lastcase = row[0]
        if not firstLine:        
            lines.append(line)
            timeseqs.append(times)
            timeseqs2.append(times2)
            timeseqs3.append(times3)
        line = ''
        times = []
        numlines+=1
    line+=chr(int(row[1])+ascii_offset)
    timesincelastevent = datetime.fromtimestamp(time.mktime(t))-datetime.fromtimestamp(time.mktime(lasteventtime))
    timesincecasestart = datetime.fromtimestamp(time.mktime(t))-datetime.fromtimestamp(time.mktime(casestarttime))
    midnight = datetime.fromtimestamp(time.mktime(t)).replace(hour=0, minute=0, second=0, microsecond=0)
    timesincemidnight = datetime.fromtimestamp(time.mktime(t))-midnight
    timediff = 86400 * timesincelastevent.days + timesincelastevent.seconds
    timediff2 = 86400 * timesincecasestart.days + timesincecasestart.seconds
    #timediff = log(timediff+1)
    times.append(timediff)
    times2.append(timediff2)
    times3.append(datetime.fromtimestamp(time.mktime(t)))
    lasteventtime = t
    firstLine = False

# add last case
lines.append(line)
timeseqs.append(times)
timeseqs2.append(times2)
timeseqs3.append(times3)
numlines+=1

# %% [markdown]
# ### Using last 1/3 as test set

# %%
fold3 = lines[2*elems_per_fold:]
fold3_c = caseids[2*elems_per_fold:]
fold3_t = timeseqs[2*elems_per_fold:]
fold3_t2 = timeseqs2[2*elems_per_fold:]
fold3_t3 = timeseqs3[2*elems_per_fold:]
#fold3_t4 = timeseqs4[2*elems_per_fold:]

lines = fold3
caseids = fold3_c
lines_t = fold3_t
lines_t2 = fold3_t2
lines_t3 = fold3_t3
#=lines_t4 = fold1_t4 + fold2_t4

# set parameters
predict_size = 1

# %% [markdown]
# # 3.Prediction

# %%
# load model, set this to the model generated by train.py
import joblib
model = joblib.load(f'output_files/models/{eventlog_name}_SVM_best_model.pkl')

# %%
print(model)
# Out:
# LabelPowerset(classifier=SVC(C=10, random_state=42), require_dense=[True, True])

# %%
# define helper functions
# Define the function to encode the input sequence
# 2 dimensional output for passing to the Random Forest model for prediction
def encode(sentence, times, times3, maxlen=maxlen):
    num_features = len(chars)+5
    X = np.zeros((1, maxlen, num_features), dtype=np.float32)
    leftpad = maxlen - len(sentence)
    times2 = np.cumsum(times)
    for t, char in enumerate(sentence):
        midnight = times3[t].replace(hour=0, minute=0, second=0, microsecond=0)
        timesincemidnight = times3[t] - midnight
        multiset_abstraction = Counter(sentence[:t+1])
        for c in chars:
            if c == char:
                X[0, t + leftpad, char_indices[c]] = 1
        X[0, t + leftpad, len(chars)] = t + 1
        X[0, t + leftpad, len(chars) + 1] = times[t] / divisor
        X[0, t + leftpad, len(chars) + 2] = times2[t] / divisor2
        X[0, t + leftpad, len(chars) + 3] = timesincemidnight.seconds / 86400
        X[0, t + leftpad, len(chars) + 4] = times3[t].weekday() / 7

    # Reshape X to be 2-dimensional
    X = X.reshape((X.shape[0], -1))

    return X

# %%
# Define the function to get the predicted symbol from the output vector
def getSymbol(predictions):
    maxIndex = np.argmax(predictions)
    symbol = target_indices_char[maxIndex]
    return symbol

# %%
one_ahead_gt = []
one_ahead_pred = []

two_ahead_gt = []
two_ahead_pred = []

three_ahead_gt = []
three_ahead_pred = []

# %%
# make predictions
with open(f'output_files/results/{eventlog_name}_SVM_next_activity_%s' % eventlog, 'w') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    spamwriter.writerow(["CaseID", "Prefix length", "Groud truth", "Predicted", "Levenshtein", "Damerau"])
    for prefix_size in range(2,maxlen):
        print(prefix_size)
        for line, caseid, times, times3 in zip(lines, caseids, lines_t, lines_t3):
            times.append(0)
            cropped_line = ''.join(line[:prefix_size])
            cropped_times = times[:prefix_size]
            cropped_times3 = times3[:prefix_size]
            if '!' in cropped_line:
                continue # make no prediction for this case, since this case has ended already
            ground_truth = ''.join(line[prefix_size:prefix_size+predict_size])
            ground_truth_t = times[prefix_size:prefix_size+predict_size]
            predicted = ''
            for i in range(predict_size):
                if len(ground_truth)<=i:
                    continue
                enc = encode(cropped_line, cropped_times, cropped_times3)
                #print(enc)
                y = model.predict(enc)
                y_char = y.toarray()
                #print('y_char:',y_char)
                prediction = getSymbol(y_char)   
                #print('prediction:' + prediction)
                cropped_line += prediction
                #print('cropped_line:' + cropped_line)
                if prediction == '!': # end of case was just predicted, therefore, stop predicting further into the future
                    print('! predicted, end case')
                    break
                predicted += prediction
             
            output = []
            
            if len(ground_truth)>0:
                output.append(caseid)
                output.append(prefix_size)
                output.append(str(ground_truth).encode("utf-8"))
                output.append(str(predicted).encode("utf-8"))
                output.append(1 - distance.nlevenshtein(predicted, ground_truth))
                dls = 1 - (damerau_levenshtein_distance(str(predicted), str(ground_truth)) / max(len(predicted),len(ground_truth)))
                if dls<0:
                    dls=0 # we encountered problems with Damerau-Levenshtein Similarity on some linux machines where the default character encoding of the operating system caused it to be negative, this should never be the case
                output.append(dls)
                output.append(1 - distance.jaccard(predicted, ground_truth))

                spamwriter.writerow(output)
# Out:
# 2
# 3
# 4
# 5
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 6
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 7
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 8
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 9
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 10
# 11
# ! predicted, end case
# ! predicted, end case
# 12
# ! predicted, end case
# 13
# ! predicted, end case
# 14
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 15
# ! predicted, end case
# 16
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 17
# ! predicted, end case
# 18
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 19
# ! predicted, end case
# 20
# ! predicted, end case
# ! predicted, end case
# 21
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 22
# 23
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 24
# ! predicted, end case
# ! predicted, end case
# 25
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 26
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 27
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 28
# ! predicted, end case
# ! predicted, end case
# 29
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 30
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 31
# ! predicted, end case
# ! predicted, end case
# 32
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 33
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 34
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 35
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 36
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 37
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 38
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 39
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 40
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 41
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 42
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 43
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 44
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 45
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 46
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 47
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 48
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 49
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 50
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 51
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 52
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 53
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 54
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 55
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 56
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 57
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 58
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 59
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 60
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 61
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 62
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 63
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 64
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 65
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 66
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 67
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 68
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 69
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 70
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 71
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 72
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 73
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 74
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 75
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 76
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 77
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 78
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 79
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 80
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 81
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 82
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# 83
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case
# ! predicted, end case

# %% [markdown]
# # 4.Evaluation

# %%
from sklearn.metrics import accuracy_score, classification_report
ground_truth = []
predicted = []
with open(f'output_files/results/{eventlog_name}_SVM_next_activity_%s' % eventlog) as file:
    reader = csv.reader(file, delimiter=",")
    # Skip the header
    next(reader, None)
    for row in reader:
        # we do not evaluate the end activity of the case
        if len(row) >= 4 and row[2] and row[3]:
            ground_truth.append(row[2])
            predicted.append(row[3])

# %%
accuracy = accuracy_score(ground_truth, predicted)
print("Next activity accuracy: ", accuracy)
print(classification_report(ground_truth, predicted))
# Out:
# Next activity accuracy:  0.1213554935500829
#               precision    recall  f1-score   support
#
#          b''       0.00      0.00      0.00         0
#  b'\xc2\xa2'       0.13      0.09      0.11        43
#  b'\xc2\xa3'       0.00      0.00      0.00         2
#  b'\xc2\xa4'       0.00      0.00      0.00         2
#  b'\xc2\xa5'       0.00      0.00      0.00         2
#  b'\xc2\xa6'       0.00      0.00      0.00         1
#  b'\xc2\xa9'       0.00      0.00      0.00         1
#  b'\xc2\xaa'       0.00      0.00      0.00         9
#  b'\xc2\xab'       0.00      0.00      0.00         1
#  b'\xc2\xac'       0.00      0.00      0.00         1
#  b'\xc2\xad'       0.00      0.00      0.00         1
#  b'\xc2\xae'       0.00      0.00      0.00         1
#  b'\xc2\xb0'       0.00      0.00      0.00         4
#  b'\xc2\xb1'       0.00      0.00      0.00         1
#  b'\xc2\xb2'       0.00      0.00      0.00         3
#  b'\xc2\xb4'       0.00      0.00      0.00         8
#  b'\xc2\xb5'       0.00      0.00      0.00         1
#  b'\xc2\xb6'       0.00      0.00      0.00        45
#  b'\xc2\xb7'       0.00      0.00      0.00        34
#  b'\xc2\xb8'       0.00      0.00      0.00        15
#  b'\xc2\xb9'       0.00      0.00      0.00        21
#  b'\xc2\xba'       0.52      0.58      0.55       538
#  b'\xc2\xbb'       0.66      0.73      0.69       584
#  b'\xc2\xbc'       0.44      0.42      0.43       580
#  b'\xc2\xbd'       0.00      0.00      0.00       524
#  b'\xc2\xbe'       0.05      0.46      0.08        72
#  b'\xc2\xbf'       0.00      0.00      0.00       210
#  b'\xc3\x80'       0.00      0.00      0.00       128
#  b'\xc3\x81'       0.18      0.21      0.19        72
#  b'\xc3\x82'       0.00      0.00      0.00       358
#  b'\xc3\x83'       0.00      0.00      0.00       243
#  b'\xc3\x84'       0.24      0.54      0.33       351
#  b'\xc3\x85'       0.00      0.00      0.00       347
#  b'\xc3\x86'       0.00      0.00      0.00         1
#  b'\xc7\xaf'       0.00      0.00      0.00        19
#  b'\xc7\xb0'       0.00      0.00      0.00        20
#  b'\xc7\xb1'       0.00      0.00      0.00        14
#  b'\xc7\xb2'       0.00      0.00      0.00        14
#  b'\xc7\xb3'       0.00      0.00      0.00         3
#  b'\xc7\xb4'       0.00      0.00      0.00         2
#  b'\xc7\xb5'       0.00      0.00      0.00         2
#  b'\xc7\xb6'       0.00      0.00      0.00         1
#  b'\xc7\xb7'       0.00      0.00      0.00         2
#  b'\xc7\xb8'       0.00      0.00      0.00         1
#  b'\xc7\xb9'       0.00      0.00      0.00        23
#  b'\xc7\xba'       0.00      0.00      0.00        17
#  b'\xc7\xbb'       0.00      0.00      0.00        17
#  b'\xc7\xbc'       0.00      0.00      0.00        10
#  b'\xc7\xbd'       0.00      0.00      0.00         1
#  b'\xc7\xbe'       0.00      0.00      0.00         1
#  b'\xc7\xbf'       0.00      0.00      0.00         1
#  b'\xc8\x80'       0.00      0.00      0.00         1
#  b'\xc8\x81'       0.00      0.00      0.00         1
#  b'\xc8\x82'       0.00      0.00      0.00         6
#  b'\xc8\x83'       0.00      0.00      0.00         1
#  b'\xc8\x84'       0.00      0.00      0.00         1
#  b'\xc8\x86'       0.00      0.00      0.00         1
#  b'\xc8\x87'       0.00      0.00      0.00         1
#  b'\xc8\x88'       0.00      0.00      0.00       158
#  b'\xc8\x89'       0.00      0.00      0.00         5
#  b'\xc8\x8a'       0.00      0.00      0.00         3
#  b'\xc8\x8b'       0.00      0.00      0.00        64
#  b'\xc8\x8c'       0.00      0.00      0.00         2
#  b'\xc8\x8d'       0.00      0.00      0.00         1
#  b'\xc8\x8e'       0.00      0.00      0.00         1
#  b'\xc8\x8f'       0.00      0.00      0.00         1
#  b'\xc8\x90'       0.00      0.00      0.00         1
#  b'\xc8\x91'       0.00      0.00      0.00         1
#  b'\xc8\x92'       0.00      0.00      0.00         1
#  b'\xc8\x93'       0.00      0.00      0.00         1
#  b'\xc8\x94'       0.00      0.00      0.00         1
#  b'\xc8\x95'       0.00      0.00      0.00         1
#  b'\xc8\x96'       0.00      0.00      0.00         1
#  b'\xc8\x97'       0.00      0.00      0.00         1
#  b'\xc8\x98'       0.00      0.00      0.00         1
#  b'\xc8\x99'       0.00      0.00      0.00         1
#  b'\xc8\x9a'       0.00      0.00      0.00         1
#  b'\xc8\x9b'       0.00      0.00      0.00         1
#  b'\xc8\x9c'       0.00      0.00      0.00        12
#  b'\xc8\x9d'       0.00      0.00      0.00         2
#  b'\xc8\x9e'       0.00      0.00      0.00         1
#
#     accuracy                           0.12     24729
#    macro avg       0.02      0.03      0.02     24729
# weighted avg       0.09      0.12      0.09     24729
# E:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# convert classification report to dataframe
report = classification_report(ground_truth, predicted, output_dict=True)
df = pd.DataFrame(report).transpose()

# Save DataFrame to CSV file
df.to_csv(f'output_files/results/{eventlog_name}_SVM_Report.csv')
# Out:
# E:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
